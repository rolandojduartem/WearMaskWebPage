# %% [markdown]
# # Wear the Mask! Convolutional Neural Network (CNN)
# ## Model development (October, 2021)
# The data set was obtained from Wang, Z. et al., 2020 (https://github.com/X-zhangyang/Real-World-Masked-Face-Dataset)<br>
# <br>
# This notebook is a kind of project that I thought about this context of pandemics. The main objective is to develop an easy but useful model to detect if a person is wearing the mask or not and then use it in production, in this link usemask.com, for potential employers as part of my portfolio. If you want to contact me, please, send me a email to rolando.duartemejias@gmail.com

# %% [markdown]
# ## Importing libraries

# %%
import os
import sklearn
import numpy as np
import pandas as pd
from glob import glob
import seaborn as sns
import tensorflow as tf
import matplotlib.pyplot as plt
# %matplotlib inline
import tensorflow.keras as keras
from sklearn.model_selection import train_test_split
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Dropout, Flatten, Dense, BatchNormalization
from tensorflow.compat.v1 import ConfigProto
from tensorflow.compat.v1 import InteractiveSession

config = ConfigProto()
config.gpu_options.allow_growth = True
session = InteractiveSession(config=config)

# %% [markdown]
# ## Preprocessing
# This step is important to know more about dataset and take decisions in the model development later

# %% [markdown]
# ### Obtaining the directory of the images and their class (1: mask, 0: no mask)
# in addition, deleting some images that cause errors in the model development.

# %%
os.chdir("./Images/")

# %%
trueDir = [x[0] for x in os.walk(".\\True\\")]
falseDir = [x[0] for x in os.walk(".\\False\\")]
trueFiles = []
falseFiles = []
allImagePathsTrue = {}
allImagePathsFalse = {}

for folder in trueDir:
    trueFilesTemp = os.listdir(folder)
    trueFiles.extend(trueFilesTemp)
    allImagePathsTemp = {os.path.basename(x): x for x in 
                   glob(os.path.join(folder, '*.jpg'))}
    allImagePathsTrue = {**allImagePathsTrue, **allImagePathsTemp}
    
for folder in falseDir:
    falseFilesTemp = os.listdir(folder)
    falseFiles.extend(falseFilesTemp)
    allImagePathsTemp = {os.path.basename(x): x for x in 
                   glob(os.path.join(folder, '*.jpg'))}
    allImagePathsFalse = {**allImagePathsFalse, **allImagePathsTemp}

trueLabels = np.ones((1, len(trueFiles)))
falseLabels = np.zeros((1, len(falseFiles)))
files = np.append(trueFiles, falseFiles)
filesLabels = np.append(trueLabels, falseLabels)
allImagePaths = {**allImagePathsTrue, **allImagePathsFalse}
df = pd.DataFrame({"Files": files, "Labels": filesLabels})
df["Labels"] = df["Labels"].astype(int)
df['Path'] = df["Files"].map(allImagePaths.get)
df.dropna(inplace = True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 92586 entries, 481 to 93611
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Files   92586 non-null  object
#  1   Labels  92586 non-null  int32
#  2   Path    92586 non-null  object
# dtypes: int32(1), object(2)
# memory usage: 2.5+ MB

# %%
df.sample(5)
# Out:
#                          Files  Labels  \
# 6346   0_0_cengyongti_0087.jpg       0
# 3764     1_0_baibaihe_0087.jpg       0
# 74468    1_0_yangyang_0216.jpg       0
# 91564     0_0_zhoujie_0106.jpg       0
# 48081  1_0_panyueming_0085.jpg       0
#
#                                              Path
# 6346   .\False\cengyongti\0_0_cengyongti_0087.jpg
# 3764       .\False\baibaihe\1_0_baibaihe_0087.jpg
# 74468      .\False\yangyang\1_0_yangyang_0216.jpg
# 91564        .\False\zhoujie\0_0_zhoujie_0106.jpg
# 48081  .\False\panyueming\1_0_panyueming_0085.jpg

# %%
count = df["Labels"].value_counts()
percentCount = df["Labels"].value_counts(normalize = True)
print(count)

fig, ax = plt.subplots(1, 2, figsize = (20, 5))
fig.suptitle("Balance of classes {0: No masked face, 2: masked face}")
ax[0].bar(percentCount.index.astype(str), percentCount.values * 100, color = ("blue", "orange"))
ax[0].set_title("Percentage of classes")
ax[0].set_xlabel("Class")
ax[0].set_ylabel("Percent of images(%)")

sns.countplot(x = "Labels", data = df)
ax[1].set_title("Total of classes")
ax[1].set_xlabel("Class")
ax[1].set_ylabel("Total of images")
ax[1].set_ylim(0, count.sum())
plt.show()
# Out:
# 0    90468
# 1     2118
# Name: Labels, dtype: int64

# %% [markdown]
# you can see more no mask cases than mask cases, this problem is called unbalanced data set, this fact must be taken to make a decision in the model development.

# %%
d = {1: "True", 0: "False"}
df["Labels"] = df["Labels"].map(d)
df.sample(5)
# Out:
#                           Files Labels  \
# 79449  1_0_zhangbaizhi_0234.jpg  False
# 3215         1_0_aidai_0069.jpg  False
# 34825    1_0_linyilian_0045.jpg  False
# 13864     1_0_fanganna_0055.jpg  False
# 61906     1_0_wangqing_0078.jpg  False
#
#                                                Path
# 79449  .\False\zhangbaizhi\1_0_zhangbaizhi_0234.jpg
# 3215               .\False\aidai\1_0_aidai_0069.jpg
# 34825      .\False\linyilian\1_0_linyilian_0045.jpg
# 13864        .\False\fanganna\1_0_fanganna_0055.jpg
# 61906        .\False\wangqing\1_0_wangqing_0078.jpg

# %% [markdown]
# ### Splitting data set to train, validate and test the model (split ratio 80% - 20%)
# In this step, how data set is unbalanced, it is necessary to split a sample from the majority class to have a balanced data set to avoid overfitting over the majority class

# %%
seed = 55

minorityClass = df[df.Labels == "True"]
print('Minority class examples: ', minorityClass.shape[0])

majorityClass = df[df.Labels == "False"]
print('Majority class examples: ', majorityClass.shape[0])

resampledClass = sklearn.utils.resample(majorityClass, replace = False, n_samples = minorityClass.shape[0], random_state = seed)
print('Resampled class examples: ', resampledClass.shape[0])

dfBalanced = pd.concat([minorityClass, resampledClass])

dfFullTrain, dfTest = train_test_split(dfBalanced, test_size = 0.2, stratify = dfBalanced.Labels, random_state = seed)
dfTrain, dfValid = train_test_split(dfFullTrain, test_size = 0.2, stratify = dfFullTrain.Labels, random_state = seed)
image_size = (64, 64)
# Out:
# Minority class examples:  2118
# Majority class examples:  90468
# Resampled class examples:  2118

# %%
print(dfTrain.shape, dfValid.shape, dfTest.shape)
# Out:
# (2710, 3) (678, 3) (848, 3)

# %% [markdown]
# The model will be trained using 6311 images, validated using 1578 images and tested using 1973 images.

# %% [markdown]
# ### Applying data augmentation
# To increase the variation of the training data set, It is important to apply data augmentation to transform the images using flips, rotaions, translations and to set different brightness to cover the possibilities when the model is in production.

# %%
batch_size = 1
train = ImageDataGenerator(rescale=1. / 255.0,
                              horizontal_flip = True,  
                              height_shift_range= 0.2, 
                              width_shift_range=0.2, 
                              rotation_range=45, 
                              shear_range = 0.2,
                              zoom_range=0.2,
                           brightness_range = (0.2, 2)
                           )

# Data generator for validation does not include random modifications
valid = ImageDataGenerator(rescale=1. / 255.0)

genTrain = train.flow_from_dataframe(  dataframe=dfTrain, 
                                         directory=None, 
                                         x_col = 'Path',
                                         y_col = 'Labels',
                                         class_mode = 'binary',
                                         target_size = image_size, 
                                         batch_size = batch_size,
                                        color_mode = "grayscale",
                                    seed = seed
                                         )

genValid = valid.flow_from_dataframe(dataframe=dfValid, 
                                  directory=None, 
                                  x_col = 'Path',
                                  y_col = 'Labels',
                                  class_mode = 'binary',
                                  target_size = image_size, 
                                  batch_size = batch_size,
                                  color_mode = "grayscale",
                                    seed = seed
                                  )

genTest = valid.flow_from_dataframe(dataframe=dfTest, 
                                  directory=None, 
                                  x_col = 'Path',
                                  y_col = 'Labels',
                                  class_mode = 'binary',
                                  target_size = image_size, 
                                  batch_size = batch_size, 
                                  color_mode = "grayscale",
                                    seed = seed
                                  )
# Out:
# Found 2710 validated image filenames belonging to 2 classes.
# Found 678 validated image filenames belonging to 2 classes.
# Found 848 validated image filenames belonging to 2 classes.

# %% [markdown]
# ### An example after applying data augmentation

# %%
t_x, t_y = next(genTrain)
fig, m_axs = plt.subplots(1, 1, figsize = (10, 10))
for (c_x, c_y) in zip(t_x, t_y):
    plt.imshow(c_x[:,:,:], cmap = 'bone')
    if c_y == 1: 
        plt.title('Mask')
    else:
        plt.title('No Mask')
    plt.axis('off')

# %% [markdown]
# ### Convolutional neural network architecture
# It will be developed a sequential CNN model with five convolutional layers, a dropout, two neural layers and an output using the sigmoid function to classify the image.

# %%
np.random.seed(seed)
tf.random.set_seed(seed)

#from tensorflow.keras.applications import MobileNetV2, MobileNetV2
#conv_base = MobileNetV2(include_top = False, weights = None, input_shape = (image_size[0], image_size[0], 1))

model = Sequential([ 
    
    #conv_base,
    
    Conv2D(filters = 32, kernel_size = (5, 5), activation = "relu", padding = "same", input_shape = (image_size[0], image_size[1], 1)),
    #BatchNormalization(),
    MaxPooling2D(pool_size = (2, 2)),
    Dropout(0.2),
    
    Conv2D(filters = 32, kernel_size = (5, 5), activation = "relu", padding = "same"),
    #BatchNormalization(),
    MaxPooling2D(pool_size = (2, 2)), 
    Dropout(0.2),
    
    Conv2D(filters = 64, kernel_size = (3, 3), activation = "relu", padding = "same"),
    #BatchNormalization(),
    MaxPooling2D(pool_size = (2, 2)),
    Dropout(0.2),
                             
    Conv2D(filters = 64, kernel_size = (3,3), activation = "relu", padding = "same"),
    #BatchNormalization(),
    MaxPooling2D(pool_size = (2, 2)),
    Dropout(0.2),
    
    #Conv2D(filters = 16, kernel_size = (3, 3), activation = "relu", padding = "same"),
    #BatchNormalization(),
    #BatchNormalization(),
    #MaxPooling2D(pool_size = (2, 2)),
    #Dropout(0.25),

    #Conv2D(filters = 16, kernel_size = (3,3), activation = "relu", padding = "same"),
    #BatchNormalization(),
    #MaxPooling2D(pool_size = (2, 2)), 
    #Dropout(0.25),

    Flatten(),
    
    Dropout(0.5),
    
    Dense(512, activation = "relu"), 
    Dense(512, activation = "relu"),

    
    Dense(1, activation = "sigmoid")
])

# %%
model.compile(loss = "binary_crossentropy",
             optimizer = keras.optimizers.Adagrad(learning_rate = 1e-3),
             metrics = [
                        keras.metrics.BinaryAccuracy(name='accuracy'),
                        keras.metrics.Precision(name='precision'),
                        keras.metrics.Recall(name='recall')
                       ])

callbackList = [keras.callbacks.EarlyStopping(patience = 10,
                                              restore_best_weights = True),
                keras.callbacks.ModelCheckpoint("../Model/bestModel.h5",
                                               save_best_only = True)]
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 64, 64, 32)        832
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 32, 32, 32)        0
# _________________________________________________________________
# dropout (Dropout)            (None, 32, 32, 32)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 32, 32, 32)        25632
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 16, 16, 32)        0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 16, 16, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 16, 16, 64)        18496
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 8, 8, 64)          0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 8, 8, 64)          0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 8, 8, 64)          36928
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 4, 4, 64)          0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 4, 4, 64)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 1024)              0
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 1024)              0
# _________________________________________________________________
# dense (Dense)                (None, 512)               524800
# _________________________________________________________________
# dense_1 (Dense)              (None, 512)               262656
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 513
# =================================================================
# Total params: 869,857
# Trainable params: 869,857
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# The best model will be saved after five epochs. I set five epoch to prevent the model from overfitting on the specifics of the images.

# %%
history = model.fit(genTrain, epochs = 1000,
                   validation_data = genValid,
                    callbacks = callbackList)
# Out:
# Epoch 1/1000
# 2710/2710 [==============================] - 45s 16ms/step - loss: 0.6924 - accuracy: 0.5209 - precision: 0.5309 - recall: 0.3776 - val_loss: 0.6819 - val_accuracy: 0.7139 - val_precision: 0.9618 - val_recall: 0.4454
# Epoch 2/1000
# 2710/2710 [==============================] - 42s 16ms/step - loss: 0.6812 - accuracy: 0.5797 - precision: 0.6082 - recall: 0.4486 - val_loss: 0.6617 - val_accuracy: 0.7257 - val_precision: 0.9581 - val_recall: 0.4720
# Epoch 3/1000
# 2710/2710 [==============================] - 40s 15ms/step - loss: 0.6540 - accuracy: 0.6276 - precision: 0.6521 - recall: 0.5492 - val_loss: 0.6481 - val_accuracy: 0.6696 - val_precision: 0.9915 - val_recall: 0.3422
# Epoch 4/1000
# 2710/2710 [==============================] - 40s 15ms/step - loss: 0.6360 - accuracy: 0.6406 - precision: 0.6584 - recall: 0.5904 - val_loss: 0.6158 - val_accuracy: 0.7360 - val_precision: 0.9762 - val_recall: 0.4838
# Epoch 5/1000
# 2710/2710 [==============================] - 42s 15ms/step - loss: 0.6182 - accuracy: 0.6380 - precision: 0.6403 - recall: 0.6560 - val_loss: 0.5600 - val_accuracy: 0.7552 - val_precision: 0.9529 - val_recall: 0.5369: 0.6
# Epoch 6/1000
# 2710/2710 [==============================] - 47s 17ms/step - loss: 0.5920 - accuracy: 0.6525 - precision: 0.6516 - recall: 0.6168 - val_loss: 0.5506 - val_accuracy: 0.7566 - val_precision: 0.9780 - val_recall: 0.5251
# Epoch 7/1000
# 2710/2710 [==============================] - 50s 18ms/step - loss: 0.5541 - accuracy: 0.7064 - precision: 0.7180 - recall: 0.6672 - val_loss: 0.5109 - val_accuracy: 0.7670 - val_precision: 0.9548 - val_recall: 0.5605
# Epoch 8/1000
# 2710/2710 [==============================] - 51s 19ms/step - loss: 0.5392 - accuracy: 0.7302 - precision: 0.7580 - recall: 0.6655 - val_loss: 0.4866 - val_accuracy: 0.7802 - val_precision: 0.9524 - val_recall: 0.5900
# Epoch 9/1000
# 2710/2710 [==============================] - 48s 18ms/step - loss: 0.5262 - accuracy: 0.7168 - precision: 0.7578 - recall: 0.6261 - val_loss: 0.4697 - val_accuracy: 0.7788 - val_precision: 0.9522 - val_recall: 0.5870
1000
# 2710/2710 [==============================] - 43s 16ms/step - loss: 0.3541 - accuracy: 0.8378 - precision: 0.8740 - recall: 0.7951 - val_loss: 0.3712 - val_accuracy: 0.8466 - val_precision: 0.7765 - val_recall: 0.9735
# Epoch 62/1000
# 2710/2710 [==============================] - 45s 17ms/step - loss: 0.3706 - accuracy: 0.8356 - precision: 0.8745 - recall: 0.7872 - val_loss: 0.3055 - val_accuracy: 0.8805 - val_precision: 0.8225 - val_recall: 0.9705
# Epoch 63/1000
# 2710/2710 [==============================] - 42s 16ms/step - loss: 0.3556 - accuracy: 0.8360 - precision: 0.8781 - recall: 0.7824 - val_loss: 0.2588 - val_accuracy: 0.9100 - val_precision: 0.8658 - val_recall: 0.9705
# Epoch 64/1000
# 2710/2710 [==============================] - 43s 16ms/step - loss: 0.3858 - accuracy: 0.8287 - precision: 0.8661 - recall: 0.7745 - val_loss: 0.3033 - val_accuracy: 0.8820 - val_precision: 0.8246 - val_recall: 0.9705
# Epoch 65/1000
# 2710/2710 [==============================] - 42s 16ms/step - loss: 0.3689 - accuracy: 0.8393 - precision: 0.8718 - recall: 0.7928 - val_loss: 0.3912 - val_accuracy: 0.8422 - val_precision: 0.7710 - val_recall: 0.9735
# Epoch 66/1000
# 2710/2710 [==============================] - 43s 16ms/step - loss: 0.3630 - accuracy: 0.8396 - precision: 0.8789 - recall: 0.7848 - val_loss: 0.2987 - val_accuracy: 0.8850 - val_precision: 0.8287 - val_recall: 0.9705

# %%
pd.DataFrame(history.history).plot(figsize = (8, 5))
plt.grid()
plt.gca().set_ylim(0, 1)
plt.gca().set_ylabel("Percentage")
plt.gca().set_xlabel("Epochs")
plt.gca().set_title("History of masked face model - CNN")
plt.show()

# %% [markdown]
# The model learnt during the epoch to improve the validation accuracy.

# %%
del model
keras.backend.clear_session()

# %%
np.random.seed(seed)
tf.random.set_seed(seed)
best_model = keras.models.load_model("../Model/bestModel.h5")
score = best_model.evaluate(genTest)
# Out:
# 848/848 [==============================] - 4s 4ms/step - loss: 0.2302 - accuracy: 0.9222 - precision: 0.9202 - recall: 0.9245

# %%
for _ in range(10):
    t_x, t_y = next(genTest)
    y_prob = best_model.predict(t_x)[:,0]
    y_pred = (y_prob>= 0.5).astype(bool)
    t_y = (t_y >= 0.5).astype(bool)
    #y_pred = (results["Predictions"]
    index = 0
    fig, m_axs = plt.subplots(1, 1, figsize = (5, 5))
    for (c_x, c_y) in zip(t_x, y_pred):
        plt.imshow(c_x[:,:,:], cmap = 'bone')
        if c_y == 1: 
            plt.title(str(t_y[index]) + ' / Mask Probability: {0:0.8f}%'.format(y_prob[index]*100), fontsize = 20)
        else:
            plt.title(str(t_y[index]) + ' / No Mask Probability: {0:0.6f}%'.format(y_prob[index]*100), fontsize = 20)
        plt.axis('off')
        index += 1
